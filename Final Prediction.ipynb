# %% [markdown]
# # Project: SnowPack Data Prediction
#
# ##### Authors: Carlos Macedo And John Pugh
# ##### Objective: Find the Amount of Snow in Berthoud Pass on March 27 2018
# ##### Due Date: 02/27/2018

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import datetime as dt

# %%
#Inputs and Data Manipulation

#Inputs
in2004 = csv.reader(open("Data2004.csv"), delimiter = "," )
in2005 = csv.reader(open("Data2005.csv"), delimiter = "," )
in2006 = csv.reader(open("Data2006.csv"), delimiter = "," )
in2007 = csv.reader(open("Data2007.csv"), delimiter = "," )
in2008 = csv.reader(open("Data2008.csv"), delimiter = "," )
in2009 = csv.reader(open("Data2009.csv"), delimiter = "," )
in2010 = csv.reader(open("Data2010.csv"), delimiter = "," )
in2011 = csv.reader(open("Data2011.csv"), delimiter = "," )
in2012 = csv.reader(open("Data2012.csv"), delimiter = "," )
in2013 = csv.reader(open("Data2013.csv"), delimiter = "," )
in2014 = csv.reader(open("Data2014.csv"), delimiter = "," )
in2015 = csv.reader(open("Data2015.csv"), delimiter = "," )
in2016 = csv.reader(open("Data2016.csv"), delimiter = "," )
in2017 = csv.reader(open("Data2017.csv"), delimiter = "," )
in2018 = csv.reader(open("Data2018.csv"), delimiter = "," )
inAvg  = csv.reader(open("Average.csv"), delimiter = "," ) #contains the average depth between 2012,2013 and 2018, all calculated on excell

#List Creation

arr4 = list(in2004)
arr5 = list(in2005)
arr6 = list(in2006)
arr7 = list(in2007)
arr8 = list(in2008)
arr9 = list(in2009)
arr10 = list(in2010)
arr11 = list(in2011)
arr12 = list(in2012)
arr13 = list(in2013)
arr14 = list(in2014)
arr15 = list(in2015)
arr16 = list(in2016)
arr17 = list(in2017)
arr18 = list(in2018)
arrAvg = list(inAvg)

#To Numpy Array 

data4 = np.array(arr4)
data5 = np.array(arr5)
data6 = np.array(arr6)
data7 = np.array(arr7)
data8 = np.array(arr8)
data9 = np.array(arr9)
data10 = np.array(arr10)
data11 = np.array(arr11)
data12 = np.array(arr12)
data13 = np.array(arr13)
data14 = np.array(arr14)
data15 = np.array(arr15)
data16 = np.array(arr16)
data17 = np.array(arr17)
data18 = np.array(arr18)
Avg = np.array(arrAvg)

# Transposition of Data

data4 = data4.T
data5 = data5.T
data6 = data6.T
data7 = data7.T
data8 = data8.T
data9 = data9.T
data10 = data10.T
data11 = data11.T
data12 = data12.T
data13 = data13.T
data14 = data14.T
data15 = data15.T
data16 = data16.T
data17 = data17.T
data18 = data18.T
Avg = Avg.T

# Variable decalrion (numbers indicate the year)


depth4 = data4[1].astype(float)
depth5 = data5[1].astype(float)
depth6 = data6[1].astype(float)
depth7 = data7[1].astype(float)
depth8 = data8[1].astype(float)
depth9 = data9[1].astype(float)
depth10 = data10[1].astype(float)
depth11 = data11[1].astype(float)
depth12 = data12[1].astype(float)
depth13 = data13[1].astype(float)
depth14 = data14[1].astype(float)
depth15 = data15[1].astype(float)
depth16 = data16[1].astype(float)
depth17 = data17[1].astype(float)
depth18 = data18[1].astype(float)
depthAvg = Avg[3].astype(float)

date04 = data4[0]
date05 = data5[0]
date06 = data6[0]
date07 = data7[0]
date08 = data8[0]
date09 = data9[0]
date010 = data10[0]
date011 = data11[0]
date012 = data12[0]
date013 = data13[0]
date014 = data14[0]
date015 = data15[0]
date016 = data16[0]
date017 = data17[0]
date018 = data18[0]
dateAvg = Avg[0]


#Create a Datetime object

#Current Year (2004)
date4 = []
for idx in range(len(date04)):
    date4 += [dt.datetime.strptime(date04[idx], "%m/%d/%Y")]
    
#Current Year (2005)
date5 = []
for idx in range(len(date05)):
    date5 += [dt.datetime.strptime(date05[idx], "%m/%d/%Y")]
    
#Current Year (2006)
date6 = []
for idx in range(len(date06)):
    date6 += [dt.datetime.strptime(date06[idx], "%m/%d/%Y")]
    
#Current Year (2007)
date7 = []
for idx in range(len(date07)):
    date7 += [dt.datetime.strptime(date07[idx], "%m/%d/%Y")]
    
#Current Year (2008)
date8 = []
for idx in range(len(date08)):
    date8 += [dt.datetime.strptime(date08[idx], "%m/%d/%Y")]

#Current Year (2009)
date9 = []
for idx in range(len(date09)):
    date9 += [dt.datetime.strptime(date09[idx], "%m/%d/%Y")]
    
#Current Year (2010)
date10 = []
for idx in range(len(date010)):
    date10 += [dt.datetime.strptime(date010[idx], "%m/%d/%Y")]
    
#Current Year (2011)
date11 = []
for idx in range(len(date011)):
    date11 += [dt.datetime.strptime(date011[idx], "%m/%d/%Y")]
    
#Current Year (2012)
date12 = []
for idx in range(len(date012)):
    date12 += [dt.datetime.strptime(date012[idx], "%m/%d/%Y")]
    
#Current Year (2013)
date13 = []
for idx in range(len(date013)):
    date13 += [dt.datetime.strptime(date013[idx], "%m/%d/%Y")]
    
#Current Year (2014)
date14 = []
for idx in range(len(date014)):
    date14 += [dt.datetime.strptime(date014[idx], "%m/%d/%Y")]
    
#Current Year (2015)
date15 = []
for idx in range(len(date015)):
    date15 += [dt.datetime.strptime(date015[idx], "%m/%d/%Y")]
    
#Current Year (2016)
date16 = []
for idx in range(len(date016)):
    date16 += [dt.datetime.strptime(date016[idx], "%m/%d/%Y")]
    
#Current Year (2017)
date17 = []
for idx in range(len(date017)):
    date17 += [dt.datetime.strptime(date017[idx], "%m/%d/%Y")]
    
#Current Year (2018)
date18 = []
for idx in range(len(date018)):
    date18 += [dt.datetime.strptime(date018[idx], "%m/%d/%Y")]

# 2013 and 2018 average

avg = []
for idx in range(len(dateAvg)):
    avg +=  [dt.datetime.strptime(dateAvg[idx], "%m/%d/%Y")]

# %%
#Overlaping Graphs 


plt.figure(figsize = (10,10))
plt.plot(depth18, label= "2018")
plt.plot(depth17, label= "2017")
plt.plot(depth16, label= "2016")
plt.plot(depth15, label= "2015")
plt.plot(depth14, label= "2014")
plt.plot(depth13, label= "2013")
plt.plot(depth12, label= "2012")
plt.plot(depth11, label= "2011")
plt.plot(depth10, label= "2010")
plt.plot(depth9, label= "2009")
plt.plot(depth8, label= "2008")
plt.plot(depth7, label= "2007")
plt.plot(depth6, label= "2006")
plt.plot(depth5, label= "2005")
plt.plot(depth4, label= "2004")

plt.xlabel("Days")
plt.ylabel("Snow Depth ( in )",fontsize = 14)
plt.title("Snow Depth Over a 15 Water Year period",)
plt.legend(loc = "upper right", title = "Year", shadow  = True, fancybox = True)
plt.show()

# %%
# La NiNa Years Plotted (All)
plt.figure(figsize = (10,10))
plt.plot(avg[0:149],depth18[0:149], label= "2018")
plt.plot(avg[0:178],depth17[0:178], label= "2017")
plt.plot(avg[0:178],depth14[0:178], label= "2014")
plt.plot(avg[0:178],depth13[0:178], label= "2013")
plt.plot(avg[0:178],depth12[0:178], label= "2012")
plt.plot(avg[0:178],depth11[0:178], label= "2011")
plt.plot(avg[0:178],depth9[0:178], label= "2009")
plt.plot(avg[0:178],depth8[0:178], label= "2008")
plt.plot(avg[0:178],depth6[0:178], label= "2006")
plt.plot(avg[0:178],depth4[0:178], label= "2004")

plt.xlabel("Days", fontsize = 14)
plt.ylabel("Snow Depth ( in )", fontsize = 14)
plt.title("Snow Depth of the last La Nina years, from October 1 to March 27, as per the Water Year Calendar")
plt.legend(loc = "upper left", title = "Year", shadow  = True, fancybox = True)
plt.show()

# %%
#Indvidual Years vs 2018

# 2004 + 2006 vs 2018
plt.figure(figsize=(10,10))

plt.subplot(121)
plt.plot(depth4)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2004 vs 2018 water year")

plt.subplot(122)
plt.plot(depth6)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2006 vs 2018 water yea")

plt.tight_layout()
plt.show()


#2008 + 2009 vs 2018

plt.figure(figsize=(10,10))

plt.subplot(121)
plt.plot(depth8)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2008 vs 2018 water year")

plt.subplot(122)
plt.plot(depth9)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2009 vs 2018 water yea")

plt.tight_layout()
plt.show()

#2011 + 2012 vs 2018

plt.figure(figsize=(10,10))

plt.subplot(121)
plt.plot(depth11)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2011 vs 2018 water year")

plt.subplot(122)
plt.plot(depth12)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2012 vs 2018 water yea")

plt.tight_layout()
plt.show()


#2013 + 2014 vs 2018

plt.figure(figsize=(10,10))

plt.subplot(121)
plt.plot(depth13)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2013 vs 2018 water year")

plt.subplot(122)
plt.plot(depth14)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2014 vs 2018 water yea")

plt.tight_layout()
plt.show()


#2015 + 2016 vs 2018

plt.figure(figsize=(10,10))

plt.subplot(121)
plt.plot(depth15)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2015 vs 2018 water year")

plt.subplot(122)
plt.plot(depth16)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2016 vs 2018 water yea")

plt.tight_layout()
plt.show()


#2017 vs 2018

plt.figure(figsize=(10,10))

plt.subplot(121)
plt.plot(depth17)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2017 vs 2018 water yea")

plt.tight_layout()
plt.show()

# %%
#Percent Difference 

PD17 = np.abs(depth18[0:148]-depth17[0:148])/((depth18[0:148]+depth17[0:148])/2)
PD14 = np.abs(depth18[0:148]-depth14[0:148])/((depth18[0:148]+depth14[0:148])/2)
PD13 = np.abs(depth18[0:148]-depth13[0:148])/((depth18[0:148]+depth13[0:148])/2)
PD12 = np.abs(depth18[0:148]-depth12[0:148])/((depth18[0:148]+depth12[0:148])/2)
PD11 = np.abs(depth18[0:148]-depth11[0:148])/((depth18[0:148]+depth11[0:148])/2)
PD8 = np.abs(depth18[0:148]-depth8[0:148])/((depth18[0:148]+depth8[0:148])/2)
PD6 = np.abs(depth18[0:148]-depth6[0:148])/((depth18[0:148]+depth6[0:148])/2)
PD4 = np.abs(depth18[0:148]-depth4[0:148])/((depth18[0:148]+depth4[0:148])/2)

av17 = np.average(PD17)
av14 = np.average(PD14)
av13 = np.average(PD13)
av12 = np.average(PD12)
av11 = np.average(PD11)
av8 = np.average(PD8)
av6 = np.average(PD6)
av4 = np.average(PD4)
# Percent Difference Comparation 

# 2017
print("The average percent difference for 2017 compared to 2018 was :", av17)

#2014
print("The average percent difference for 2014 compared to 2018 was :", av14)

#2013
print("The average percent difference for 2013 compared to 2018 was :", av13)

#2012
print("The average percent difference for 2012 compared to 2018 was :", av12)

#2011
print("The average percent difference for 2011 compared to 2018 was :", av11)

#2008
print("The average percent difference for 2008 compared to 2018 was :", av8)

#2006
print("The average percent difference for 2006 compared to 2018 was :", av6)

#2004
\
print("The average percent difference for 2004 compared to 2018 was :", av4)

print("\n The Years with the least percent difference with 2018 form 1/October and 27/March are:\n ",
      "2008,2012,2013")
# Out:
# The average percent difference for 2017 compared to 2018 was : 0.851854636932
# The average percent difference for 2014 compared to 2018 was : 0.740474617175
# The average percent difference for 2013 compared to 2018 was : 0.635337655278
# The average percent difference for 2012 compared to 2018 was : 0.431333210338
# The average percent difference for 2011 compared to 2018 was : 0.765186486345
# The average percent difference for 2008 compared to 2018 was : 0.632882651961
# The average percent difference for 2006 compared to 2018 was : 0.75464743516
# The average percent difference for 2004 compared to 2018 was : 0.660449780717
#
#  The Years with the least percent difference with 2018 form 1/October and 27/March are:
#   2008,2012,2013

# %%
# Plot of The closer Years long with the average (Closer ones)

plt.figure(figsize = (10,10)) 
plt.plot(avg[0:149],depth18, label= "2018")
plt.plot(avg[0:149],depth13[0:149], label= "2013")
plt.plot(avg[0:149],depth12[0:149], label= "2012")
plt.plot(avg[0:149],depth8[0:149], label= "2008")
plt.plot(avg[0:149],depthAvg[0:149], label = "Average of The above years")

plt.xlabel("Days", fontsize = 14)
plt.ylabel("Snow Depth ( in )", fontsize = 14)
plt.title("Snow Depth of the last La Nina Years, from October 1 to March 27, as per the Water Year Calendar")
plt.legend(loc = "upper left", title = "Year", shadow  = True, fancybox = True)
plt.show()

print("Eventhough 2008 has a small percent difference with the2018 data, 2012 and 2013 have a closer graph to the current" 
     + "2018 trend")
# Out:
# Eventhough 2008 has a small percent difference with the2018 data, 2012 and 2013 have a closer graph to the current2018 trend

# %%
## Plot of The 2013 along with the average (Closer ones)

plt.figure(figsize = (10,10))
plt.plot(avg[0:149],depth18, label= "2018")
plt.plot(avg[0:149],depth12[0:149], label= "2012")
plt.plot(avg[0:149],depth13[0:149], label= "2013")
plt.plot(avg[0:149],depthAvg[0:149], label = "Average of the years above")

plt.xlabel("Days", fontsize = 14)
plt.ylabel("Snow Depth ( in )", fontsize = 14)
plt.title("Years Following the same Patter as 2018 from October 1 to March 27, as per the Water Year Calendar")
plt.legend(loc = "upper left", title = "Year", shadow  = True, fancybox = True)
plt.show()

# %%
# Polyfit and Function for average data
#(The Polinomial of the polyfit was choosen because ir fits the data more appropriatly)


p_projection = np.polyfit(np.arange(0,len(avg)),depthAvg,14)
projection_function = np.poly1d(p_projection)



plt.figure(figsize = (10,10))
plt.plot(avg[0:149],projection_function(np.arange(len(avg[0:149]))), label = "Fitted Fuction")
plt.plot(avg[0:149],depthAvg[0:149], label = " Average function" )
plt.plot(avg[0:149],depth18, label = " 2018")
plt.plot
plt.xlabel("Day", fontsize = 14)
plt.ylabel("Snow Depth ( in )", fontsize = 14)
plt.title("Average Data and Fitted Function for 2018 ",fontsize = 14)
plt.legend(loc = "upper left", title = "Year", shadow  = True, fancybox = True)
plt.show()

# %%
# Average Projection

#Error (percent error)
a=projection_function(np.arange(len(avg)))
x=np.arange(0,len(avg))
error = (np.abs((depthAvg-projection_function(np.arange(len(avg)))))/np.sqrt((depthAvg)**2+(projection_function(np.arange(len(avg))))**2))*100
for i in range(len(depthAvg)):
    error[i]=(depthAvg[i])*(error[i]/100)

#Standard Deviation
std = np.std(np.abs(depthAvg-projection_function(np.arange(len(date13)))))


p_projection = np.polyfit(np.arange(0,len(avg)),depthAvg,15)
projection_function = np.poly1d(p_projection)



plt.figure(figsize = (10,10))
plt.plot(177,a[177],'D',color = 'r', label ="March 27 2018 Snowdepth Predicted value \n(%f +- %s)"%(a[177],std))
plt.plot(projection_function(np.arange(len(date13))), label = "Predicted Values",linewidth = 2.0, color= 'b')
plt.plot(depthAvg, label = " Average Data ", color = 'K' )
plt.errorbar(x,projection_function(np.arange(len(avg))),error,errorevery =1.5, fmt = "--",ecolor='b', label = "Error Bar (Percent Difference)")

plt.xlabel("Day", fontsize = 14)
plt.ylabel("Snow Depth ( in )", fontsize = 14)

plt.xlim(93,200)
plt.ylim (20,50)
plt.title("Predicted Snowdepth for 2018 ",fontsize = 14)
plt.legend(loc = "upper left", title = "Year", shadow  = True, fancybox = True)
plt.tight_layout()
plt.show()

prediction = depthAvg[177]
d1 = avg[177]
print(d1)
print( "Prediction Value",prediction )


print("Standard Diviation",std)
# Out:
# 2018-03-27 00:00:00
# Prediction Value 43.0
# Standard Diviation 1.57179585697

# %%
a=projection_function(np.arange(len(avg)))
print("The Predicetd Value is:")
print(a[177], "+-", error[177])
# Out:
# The Predicetd Value is:
# 44.4386198429 +- 1.00038560131
