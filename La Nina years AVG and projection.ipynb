# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import datetime as dt

# %%
#Inputs

in2004 = csv.reader(open("Data2004.csv"), delimiter = "," )
in2006 = csv.reader(open("Data2006.csv"), delimiter = "," )
in2008 = csv.reader(open("Data2008.csv"), delimiter = "," )
in2009 = csv.reader(open("Data2009.csv"), delimiter = "," )
in2011 = csv.reader(open("Data2011.csv"), delimiter = "," )
in2012 = csv.reader(open("Data2012.csv"), delimiter = "," )
in2013 = csv.reader(open("Data2013.csv"), delimiter = "," )
in2014 = csv.reader(open("Data2014.csv"), delimiter = "," )
in2017 = csv.reader(open("Data2017.csv"), delimiter = "," )
in2018 = csv.reader(open("Data2018.csv"), delimiter = "," )

# %%
arr4 = list(in2004)
arr6 = list(in2006)
arr8 = list(in2008)
arr9 = list(in2009)
arr11 = list(in2011)
arr12 = list(in2012)
arr13 = list(in2013)
arr14 = list(in2014)
arr17 = list(in2017)
arr18 = list(in2018)

# %%
#To Numpy Array

data4 = np.array(arr4)
data6 = np.array(arr6)
data8 = np.array(arr8)
data9 = np.array(arr9)
data11 = np.array(arr11)
data12 = np.array(arr12)
data13 = np.array(arr13)
data14 = np.array(arr14)
data17 = np.array(arr17)
data18 = np.array(arr18)

# %%
data4 = data4.T
data6 = data6.T
data8 = data8.T
data9 = data9.T
data11 = data11.T
data12 = data12.T
data13 = data13.T
data14 = data14.T
data17 = data17.T
data18 = data18.T

# %%
# Depth declaration


depth4 = data4[1].astype(float)
depth6 = data6[1].astype(float)
depth8 = data8[1].astype(float)
depth9 = data9[1].astype(float)
depth11 = data11[1].astype(float)
depth12 = data12[1].astype(float)
depth13 = data13[1].astype(float)
depth14 = data14[1].astype(float)
depth17 = data17[1].astype(float)
depth18 = data18[1].astype(float)

date04 = data4[0]
date06 = data6[0]
date08 = data8[0]
date09 = data9[0]
date011 = data11[0]
date012 = data12[0]
date013 = data13[0]
date014 = data14[0]
date017 = data17[0]
date018 = data18[0]

# %%
#Create a Datetime object

#Current Year (2004)
date4 = []
for idx in range(len(date04)):
    date4 += [dt.datetime.strptime(date04[idx], "%m/%d/%Y")]
    

#Current Year (2006)
date6 = []
for idx in range(len(date06)):
    date6 += [dt.datetime.strptime(date06[idx], "%m/%d/%Y")]
    
    
#Current Year (2008)
date8 = []
for idx in range(len(date08)):
    date8 += [dt.datetime.strptime(date08[idx], "%m/%d/%Y")]

#Current Year (2009)
date9 = []
for idx in range(len(date09)):
    date9 += [dt.datetime.strptime(date09[idx], "%m/%d/%Y")]
    

#Current Year (2011)
date11 = []
for idx in range(len(date011)):
    date11 += [dt.datetime.strptime(date011[idx], "%m/%d/%Y")]
    
#Current Year (2012)
date12 = []
for idx in range(len(date012)):
    date12 += [dt.datetime.strptime(date012[idx], "%m/%d/%Y")]
    
#Current Year (2013)
date13 = []
for idx in range(len(date013)):
    date13 += [dt.datetime.strptime(date013[idx], "%m/%d/%Y")]
    
#Current Year (2014)
date14 = []
for idx in range(len(date014)):
    date14 += [dt.datetime.strptime(date014[idx], "%m/%d/%Y")]
    

#Current Year (2017)
date17 = []
for idx in range(len(date017)):
    date17 += [dt.datetime.strptime(date017[idx], "%m/%d/%Y")]
    
#Current Year (2018)
date18 = []
for idx in range(len(date018)):
    date18 += [dt.datetime.strptime(date018[idx], "%m/%d/%Y")]

# %%
plt.figure(figsize = (10,10))
plt.plot(depth18, label= "2018")
plt.plot(depth17, label= "2017")
plt.plot(depth14, label= "2014")
plt.plot(depth13, label= "2013")
plt.plot(depth12, label= "2012")
plt.plot(depth11, label= "2011")
plt.plot(depth9, label= "2009")
plt.plot(depth8, label= "2008")
plt.plot(depth6, label= "2006")
plt.plot(depth4, label= "2006")

plt.xlabel("Days")
plt.ylabel("Snow Depth ( in )")
plt.title("Snow Depth Over a 5 Water Year period")
plt.legend(loc = "upper right", title = "Year", shadow  = True, fancybox = True)
plt.show()

# %%
plt.figure(figsize = (10,10))
plt.plot(depth18[0:175], label= "2018")
plt.plot(depth17[0:175], label= "2017")
plt.plot(depth14[0:175], label= "2014")
plt.plot(depth13[0:175], label= "2013")
plt.plot(depth12[0:175], label= "2012")
plt.plot(depth11[0:175], label= "2011")
plt.plot(depth9[0:175], label= "2009")
plt.plot(depth8[0:175], label= "2008")
plt.plot(depth6[0:175], label= "2006")
plt.plot(depth4[0:175], label= "2006")

plt.xlabel("Days")
plt.ylabel("Snow Depth ( in )")
plt.title("Snow Depth Over a 5 Water Year period")
plt.legend(loc = "upper right", title = "Year", shadow  = True, fancybox = True)
plt.show()

# %%
plt.figure(figsize = (10,10))
plt.plot(date18 , depth18, label= "2018")
plt.plot(date17 , depth17, label= "2017")
plt.plot(date14 , depth14, label= "2014")
plt.plot(date13 , depth13, label= "2013")
plt.plot(date12 , depth12, label= "2012")
plt.plot(date11 , depth11, label= "2011")
plt.plot(date9 , depth9, label= "2009")
plt.plot(date8 , depth8, label= "2008")
plt.plot(date6 , depth6, label= "2006")
plt.plot(date4 , depth4, label= "2006")


plt.xlabel("Years")
plt.ylabel("Snow Depth ( in )")
plt.title("Snow Depth Over a 15 Water Year period")
plt.legend(loc = "upper right", title = "Year", shadow  = True, fancybox = True)
plt.show()

# %%
#Indvidual Years vs 2018

# 2004 + 2006 vs 2018
plt.figure(figsize=(10,10))

plt.subplot(121)
plt.plot(depth4)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2004 vs 2018 water year")

plt.subplot(122)
plt.plot(depth6)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2006 vs 2018 water yea")

plt.tight_layout()
plt.show()


#2008 + 2009 vs 2018

plt.figure(figsize=(10,10))

plt.subplot(121)
plt.plot(depth8)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2008 vs 2018 water year")

plt.subplot(122)
plt.plot(depth9)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2009 vs 2018 water yea")

plt.tight_layout()
plt.show()

#2011 + 2012 vs 2018

plt.figure(figsize=(10,10))

plt.subplot(121)
plt.plot(depth11)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2011 vs 2018 water year")

plt.subplot(122)
plt.plot(depth9)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2012 vs 2018 water yea")

plt.tight_layout()
plt.show()


#2013 + 2014 vs 2018

plt.figure(figsize=(10,10))

plt.subplot(121)
plt.plot(depth13)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2013 vs 2018 water year")

plt.subplot(122)
plt.plot(depth14)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2014 vs 2018 water yea")

plt.tight_layout()
plt.show()


#2016 + 2017 vs 2018

plt.figure(figsize=(10,10))

plt.subplot(121)
plt.plot(depth12)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2012 vs 2018 water year")

plt.subplot(122)
plt.plot(depth13)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2013 vs 2018 water yea")

plt.tight_layout()
plt.show()


#2014 + 2017 vs 2018

plt.figure(figsize=(10,10))

plt.subplot(121)
plt.plot(depth14)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2014 vs 2018 water year")

plt.subplot(122)
plt.plot(depth17)
plt.plot(depth18)
plt.xlabel("Days")
plt.ylabel("Snow Depth (in) ")
plt.title("Snow Depth: 2017 vs 2018 water yea")

plt.tight_layout()
plt.show()

# %%
# Using fit to find coefficients of the functions

p4 = np.polyfit(np.arange(0,len(date4)),depth4,2)
p6 = np.polyfit(np.arange(0,len(date6)),depth6,2)
p8 = np.polyfit(np.arange(0,len(date8)),depth8,2)
p9 = np.polyfit(np.arange(0,len(date9)),depth9,2)
p11 = np.polyfit(np.arange(0,len(date11)),depth11,2)
p12 = np.polyfit(np.arange(0,len(date12)),depth12,2)
p13 = np.polyfit(np.arange(0,len(date13)),depth13,2)
p14 = np.polyfit(np.arange(0,len(date14)),depth14,2)
p17 = np.polyfit(np.arange(0,len(date17)),depth17,2)
p18 = np.polyfit(np.arange(0,len(date18)),depth18,2)

#Using poly1d to create functions
z4 = np.poly1d(p4)
z6 = np.poly1d(p4)
z8 = np.poly1d(p4)
z9 = np.poly1d(p4)
z11 = np.poly1d(p4)
z12 = np.poly1d(p4)
z13 = np.poly1d(p4)
z14 = np.poly1d(p4)
z17 = np.poly1d(p4)
z18 = np.poly1d(p4)

# %%
#Plot of Average of important graphs as well as their functions

# %%
#Final Prediction
